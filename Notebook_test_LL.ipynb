# %%
import pandas as pd 
import get_journey_sncf_now as gjn


df = gjn.get_OD_now(ville_origine='Bordeaux',nb_trajets=2,etranger=False,niveau_service=2,minutes_max=120)
df

# %%
tab = pd.read_csv('Outputs/results_Bordeaux_20221213T135825.csv')
tab

# %%
import affichage_vol_dest as avd

tab2 =avd.vol_dest_api('BOD')
tab2
# Out:
#                                                  id_x flyFrom code  cityFrom  \
# 0                          049801af4b9600003e9fae8d_0     BOD  BCN  Bordeaux
# 1                          04980a224b960000539921e2_0     BOD  MAD  Bordeaux
# 2                          049823fa4b9600002e22280e_0     BOD  GVA  Bordeaux
# 3                          049822f54b9600008be0ae1f_0     BOD  LGW  Bordeaux
# 4                          049804c84b950000e86dabc6_0     BOD  FLR  Bordeaux
# 5                          04981fb04b950000e7295b3d_0     BOD  VCE  Bordeaux
# 6                          0498091e4b9400005f96d60c_0     BOD  CRL  Bordeaux
# 7                          04981fb04b93000066bc47bb_0     BOD  VCE  Bordeaux
# 8   04980f354b960000c4cf73c9_0|04980f354b960000c4c...     BOD  IBZ  Bordeaux
# 9                          049825584b9500004cc6ef0c_0     BOD  BGY  Bordeaux
# 10                         049822f54b9300006e153524_0     BOD  LGW  Bordeaux
# 11                         049822f54b93000057780bdc_0     BOD  LGW  Bordeaux
# 12                         049823fa4b9400005ee5b981_0     BOD  GVA  Bordeaux
# 13  049813a24b9600007f4d6aac_0|049813a24b9600007f4...     BOD  PMI  Bordeaux
# 14                         049803584b950000ae81d2cd_0     BOD  LIS  Bordeaux
# 15                         049823fa4b9300002c6f9e32_0     BOD  GVA  Bordeaux
# 16  049813a24b960000abc6910c_0|049813a24b960000abc...     BOD  PMI  Bordeaux
# 17  04980f0c4b96000019af33a1_0|04980f0c4b96000019a...     BOD  FCO  Bordeaux
# 18                         049803584b950000ef1bcc38_0     BOD  LIS  Bordeaux
# 19                         049803584b9600006cc36682_0     BOD  LIS  Bordeaux
# 20  049803464b960000f8dd4613_0|049803464b960000f8d...     BOD  NCE  Bordeaux
# 21                         049822f54b950000083804a5_0     BOD  LGW  Bordeaux
# 22                         049822f54b950000ef8029a2_0     BOD  LGW  Bordeaux
# 23                         049803464b940000cac5fa59_0     BOD  NCE  Bordeaux
# 24                         049803464b95000039dac16c_0     BOD  NCE  Bordeaux
# 25                         049811d74b940000c52a74cc_0     BOD  RAK  Bordeaux
# 26                         04980a224b9500009487974e_0     BOD  MAD  Bordeaux
# 27  049825c34b964ba70a4eff59_0|049825c34b964ba70a4...     BOD  CDG  Bordeaux
# 28  049825c34b954ba723d50da7_0|049825c34b954ba723d...     BOD  CDG  Bordeaux
# 29  049825c34b944ba72542007b_0|049825c34b944ba7254...     BOD  CDG  Bordeaux
# 30                         049823fa4b950000adfa82b4_0     BOD  GVA  Bordeaux
# 31                         04980e354b9400002ad685a3_0     BOD  LYS  Bordeaux
# 32                         0498249d4b9600008a8cde6e_0     BOD  ALG  Bordeaux
# 33                         04980cb54b9500009b97426d_0     BOD  BSL  Bordeaux
# 34  049810e84b940000cdab3529_0|049810e84b940000cda...     BOD  AMS  Bordeaux
# 35                         049803464b930000b84fddea_0     BOD  NCE  Bordeaux
# 36                         049800ed4b94000047923eb4_0     BOD  MRS  Bordeaux
# 37                         04980e354b940000cd6ea8a4_0     BOD  LYS  Bordeaux
# 38                         0498093e4b950000195586f3_0     BOD  OPO  Bordeaux
# 39  04980e354b944ba216190be6_0|04980e354b944ba2161...     BOD  LYS  Bordeaux
# 40                         0498034c4b940000a1bf3d83_0     BOD  LIL  Bordeaux
# 41  04980e354b954b9f02bc739e_0|04980e354b954b9f02b...     BOD  LYS  Bordeaux
# 42                         049800ed4b950000b48d0581_0     BOD  MRS  Bordeaux
# 43                         049825c34b950000337e9e51_0     BOD  CDG  Bordeaux
# 44                         049825c34b9400003ec2b922_0     BOD  CDG  Bordeaux
# 45                         049825c34b940000c061a564_0     BOD  CDG  Bordeaux
# 46                         049825c34b950000cddd8217_0     BOD  CDG  Bordeaux
# 47                         0498060c4b960000b7936e27_0     BOD  LUX  Bordeaux
# 48  04980a224b9300005a10ba6e_0|04980a224b9300005a1...     BOD  MAD  Bordeaux
# 49  049810e84b930000566cafb8_0|049810e84b930000566...     BOD  AMS  Bordeaux
# 50  049801af4b93000019db9d06_0|049801af4b93000019d...     BOD  BCN  Bordeaux
# 51  049801af4b9300001eb6591f_0|049801af4b9300001eb...     BOD  BCN  Bordeaux
# 52  04980a224b930000433b9d4d_0|04980a224b930000433...     BOD  MAD  Bordeaux
# 53  04980a224b9300007e840657_0|04980a224b9300007e8...     BOD  MAD  Bordeaux
# 54  04980a224b930000997758a5_0|04980a224b930000997...     BOD  MAD  Bordeaux
# 55  049821dd4b93000097719492_0|049821dd4b930000977...     BOD  DXB  Bordeaux
# 56  04980a224b93000077793989_0|04980a224b930000777...     BOD  MAD  Bordeaux
#
#    cityCodeFrom           cityTo cityCodeTo                       countryFrom  \
# 0           BOD        Barcelona        BCN  {'code': 'FR', 'name': 'France'}
# 1           BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 2           BOD           Geneva        GVA  {'code': 'FR', 'name': 'France'}
# 3           BOD           London        LON  {'code': 'FR', 'name': 'France'}
# 4           BOD         Florence        FLR  {'code': 'FR', 'name': 'France'}
# 5           BOD           Venice        VCE  {'code': 'FR', 'name': 'France'}
# 6           BOD         Brussels        BRU  {'code': 'FR', 'name': 'France'}
# 7           BOD           Venice        VCE  {'code': 'FR', 'name': 'France'}
# 8           BOD            Ibiza        IBZ  {'code': 'FR', 'name': 'France'}
# 9           BOD            Milan        MIL  {'code': 'FR', 'name': 'France'}
# 10          BOD           London        LON  {'code': 'FR', 'name': 'France'}
# 11          BOD           London        LON  {'code': 'FR', 'name': 'France'}
# 12          BOD           Geneva        GVA  {'code': 'FR', 'name': 'France'}
# 13          BOD   Palma, Majorca        PMI  {'code': 'FR', 'name': 'France'}
# 14          BOD           Lisbon        LIS  {'code': 'FR', 'name': 'France'}
# 15          BOD           Geneva        GVA  {'code': 'FR', 'name': 'France'}
# 16          BOD   Palma, Majorca        PMI  {'code': 'FR', 'name': 'France'}
# 17          BOD             Rome        ROM  {'code': 'FR', 'name': 'France'}
# 18          BOD           Lisbon        LIS  {'code': 'FR', 'name': 'France'}
# 19          BOD           Lisbon        LIS  {'code': 'FR', 'name': 'France'}
# 20          BOD             Nice        NCE  {'code': 'FR', 'name': 'France'}
# 21          BOD           London        LON  {'code': 'FR', 'name': 'France'}
# 22          BOD           London        LON  {'code': 'FR', 'name': 'France'}
# 23          BOD             Nice        NCE  {'code': 'FR', 'name': 'France'}
# 24          BOD             Nice        NCE  {'code': 'FR', 'name': 'France'}
# 25          BOD        Marrakesh        RAK  {'code': 'FR', 'name': 'France'}
# 26          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 27          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 28          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 29          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 30          BOD           Geneva        GVA  {'code': 'FR', 'name': 'France'}
# 31          BOD             Lyon        LYS  {'code': 'FR', 'name': 'France'}
# 32          BOD          Algiers        ALG  {'code': 'FR', 'name': 'France'}
# 33          BOD            Basel        EAP  {'code': 'FR', 'name': 'France'}
# 34          BOD        Amsterdam        AMS  {'code': 'FR', 'name': 'France'}
# 35          BOD             Nice        NCE  {'code': 'FR', 'name': 'France'}
# 36          BOD        Marseille        MRS  {'code': 'FR', 'name': 'France'}
# 37          BOD             Lyon        LYS  {'code': 'FR', 'name': 'France'}
# 38          BOD            Porto        OPO  {'code': 'FR', 'name': 'France'}
# 39          BOD             Lyon        LYS  {'code': 'FR', 'name': 'France'}
# 40          BOD            Lille        LIL  {'code': 'FR', 'name': 'France'}
# 41          BOD             Lyon        LYS  {'code': 'FR', 'name': 'France'}
# 42          BOD        Marseille        MRS  {'code': 'FR', 'name': 'France'}
# 43          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 44          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 45          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 46          BOD            Paris        PAR  {'code': 'FR', 'name': 'France'}
# 47          BOD  Luxembourg City        LUX  {'code': 'FR', 'name': 'France'}
# 48          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 49          BOD        Amsterdam        AMS  {'code': 'FR', 'name': 'France'}
# 50          BOD        Barcelona        BCN  {'code': 'FR', 'name': 'France'}
# 51          BOD        Barcelona        BCN  {'code': 'FR', 'name': 'France'}
# 52          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 53          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 54          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
# 55          BOD            Dubai        DXB  {'code': 'FR', 'name': 'France'}
# 56          BOD           Madrid        MAD  {'code': 'FR', 'name': 'France'}
#
#                                          countryTo nightsInDest  ...  \
# 0                  {'code': 'ES', 'name': 'Spain'}         None  ...
# 1                  {'code': 'ES', 'name': 'Spain'}         None  ...
# 2            {'code': 'CH', 'name': 'Switzerland'}         None  ...
# 3         {'code': 'GB', 'name': 'United Kingdom'}         None  ...
# 4                  {'code': 'IT', 'name': 'Italy'}         None  ...
# 5                  {'code': 'IT', 'name': 'Italy'}         None  ...
# 6                {'code': 'BE', 'name': 'Belgium'}         None  ...
# 7                  {'code': 'IT', 'name': 'Italy'}         None  ...
# 8                  {'code': 'ES', 'name': 'Spain'}         None  ...
# 9                  {'code': 'IT', 'name': 'Italy'}         None  ...
# 10        {'code': 'GB', 'name': 'United Kingdom'}         None  ...
# 11        {'code': 'GB', 'name': 'United Kingdom'}         None  ...
# 12           {'code': 'CH', 'name': 'Switzerland'}         None  ...
# 13                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 14              {'code': 'PT', 'name': 'Portugal'}         None  ...
# 15           {'code': 'CH', 'name': 'Switzerland'}         None  ...
# 16                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 17                 {'code': 'IT', 'name': 'Italy'}         None  ...
# 18              {'code': 'PT', 'name': 'Portugal'}         None  ...
# 19              {'code': 'PT', 'name': 'Portugal'}         None  ...
# 20                {'code': 'FR', 'name': 'France'}         None  ...
# 21        {'code': 'GB', 'name': 'United Kingdom'}         None  ...
# 22        {'code': 'GB', 'name': 'United Kingdom'}         None  ...
# 23                {'code': 'FR', 'name': 'France'}         None  ...
# 24                {'code': 'FR', 'name': 'France'}         None  ...
# 25               {'code': 'MA', 'name': 'Morocco'}         None  ...
# 26                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 27                {'code': 'FR', 'name': 'France'}         None  ...
# 28                {'code': 'FR', 'name': 'France'}         None  ...
# 29                {'code': 'FR', 'name': 'France'}         None  ...
# 30           {'code': 'CH', 'name': 'Switzerland'}         None  ...
# 31                {'code': 'FR', 'name': 'France'}         None  ...
# 32               {'code': 'DZ', 'name': 'Algeria'}         None  ...
# 33           {'code': 'CH', 'name': 'Switzerland'}         None  ...
# 34           {'code': 'NL', 'name': 'Netherlands'}         None  ...
# 35                {'code': 'FR', 'name': 'France'}         None  ...
# 36                {'code': 'FR', 'name': 'France'}         None  ...
# 37                {'code': 'FR', 'name': 'France'}         None  ...
# 38              {'code': 'PT', 'name': 'Portugal'}         None  ...
# 39                {'code': 'FR', 'name': 'France'}         None  ...
# 40                {'code': 'FR', 'name': 'France'}         None  ...
# 41                {'code': 'FR', 'name': 'France'}         None  ...
# 42                {'code': 'FR', 'name': 'France'}         None  ...
# 43                {'code': 'FR', 'name': 'France'}         None  ...
# 44                {'code': 'FR', 'name': 'France'}         None  ...
# 45                {'code': 'FR', 'name': 'France'}         None  ...
# 46                {'code': 'FR', 'name': 'France'}         None  ...
# 47            {'code': 'LU', 'name': 'Luxembourg'}         None  ...
# 48                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 49           {'code': 'NL', 'name': 'Netherlands'}         None  ...
# 50                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 51                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 52                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 53                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 54                 {'code': 'ES', 'name': 'Spain'}         None  ...
# 55  {'code': 'AE', 'name': 'United Arab Emirates'}         None  ...
# 56                 {'code': 'ES', 'name': 'Spain'}         None  ...
#
#     new_ground  routing_priority     type        lat        lon  \
# 0        False               0.0  airport  41.296944   2.078333
# 1        False               0.0  airport  40.493611  -3.566667
# 2        False               0.0  airport  46.238056   6.108889
# 3        False               0.0  airport  51.148056  -0.190278
# 4        False               0.0  airport  43.808611  11.202778
# 5        False               0.0  airport  45.505278  12.351944
# 6        False               0.0  airport  50.459167   4.453889
# 7        False               0.0  airport  45.505278  12.351944
# 8        False               0.0  airport  38.872778   1.373056
# 9        False               0.0  airport  45.668889   9.700278
# 10       False               0.0  airport  51.148056  -0.190278
# 11       False               0.0  airport  51.148056  -0.190278
# 12       False               0.0  airport  46.238056   6.108889
# 13       False               0.0  airport  39.551667   2.738889
# 14       False               0.0  airport  38.774167  -9.134167
# 15       False               0.0  airport  46.238056   6.108889
# 16       False               0.0  airport  39.551667   2.738889
# 17       False               0.0  airport  41.800278  12.238889
# 18       False               0.0  airport  38.774167  -9.134167
# 19       False               0.0  airport  38.774167  -9.134167
# 20       False               0.0  airport  43.665278   7.215000
# 21       False               0.0  airport  51.148056  -0.190278
# 22       False               0.0  airport  51.148056  -0.190278
# 23       False               0.0  airport  43.665278   7.215000
# 24       False               0.0  airport  43.665278   7.215000
# 25         NaN               NaN      NaN        NaN        NaN
# 26       False               0.0  airport  40.493611  -3.566667
# 27       False               0.0  airport  49.009722   2.547778
# 28       False               0.0  airport  49.009722   2.547778
# 29       False               0.0  airport  49.009722   2.547778
# 30       False               0.0  airport  46.238056   6.108889
# 31       False               0.0  airport  45.725556   5.081111
# 32       False               0.0  airport  36.694167   3.214722
# 33       False               0.0  airport  47.601111   7.521667
# 34       False               0.0  airport  52.308056   4.764167
# 35       False               0.0  airport  43.665278   7.215000
# 36       False               0.0  airport  43.436667   5.215000
# 37       False               0.0  airport  45.725556   5.081111
# 38       False               0.0  airport  41.235556  -8.678056
# 39       False               0.0  airport  45.725556   5.081111
# 40       False               0.0  airport  50.563333   3.086944
# 41       False               0.0  airport  45.725556   5.081111
# 42       False               0.0  airport  43.436667   5.215000
# 43       False               0.0  airport  49.009722   2.547778
# 44       False               0.0  airport  49.009722   2.547778
# 45       False               0.0  airport  49.009722   2.547778
# 46       False               0.0  airport  49.009722   2.547778
# 47       False               0.0  airport  49.623333   6.204444
# 48       False               0.0  airport  40.493611  -3.566667
# 49       False               0.0  airport  52.308056   4.764167
# 50       False               0.0  airport  41.296944   2.078333
# 51       False               0.0  airport  41.296944   2.078333
# 52       False               0.0  airport  40.493611  -3.566667
# 53       False               0.0  airport  40.493611  -3.566667
# 54       False               0.0  airport  40.493611  -3.566667
# 55         NaN               NaN      NaN        NaN        NaN
# 56       False               0.0  airport  40.493611  -3.566667
#
#         Tps_trajet              Tps_total Tps_trajet_sec Tps_total_sec  \
# 0  0 days 01:01:00 3 days 05:50:39.601693           3660         21000
# 1  0 days 01:03:00 3 days 02:52:39.601693           3780         10320
# 2  0 days 01:56:00 3 days 05:48:39.601693           6960         20880
# 3  0 days 01:04:00 2 days 23:52:39.601693           3840         85920
# 4  0 days 01:58:00 2 days 04:50:39.601693           7080         17400
# 5  0 days 01:59:00 2 days 06:48:39.601693           7140         24480
# 6  0 days 01:03:00 1 days 02:51:39.601693           3780         10260
# 7  0 days 02:00:00 0 days 06:52:39.601693           7200         24720
# 8  0 days 12:59:00 3 days 17:48:39.601693          46740         64080
# 9  0 days 01:03:00 2 days 00:53:39.601693           3780          3180
# 10 0 days 01:03:00 0 days 04:53:39.601693           3780         17580
# 11 0 days 01:58:00 0 days 05:48:39.601693           7080         20880
# 12 0 days 01:02:00 1 days 05:53:39.601693           3720         21180
# 13 0 days 10:01:00 3 days 14:50:39.601693          36060         53400
# 14 0 days 01:05:00 2 days 05:53:39.601693           3900         21180
# 15 0 days 01:02:00 0 days 05:53:39.601693           3720         21180
# 16 0 days 05:04:00 3 days 06:53:39.601693          18240         24780
# 17 0 days 11:04:00 3 days 15:53:39.601693          39840         57180
# 18 0 days 01:05:00 1 days 23:53:39.601693           3900         85980
# 19 0 days 01:05:00 2 days 23:53:39.601693           3900         85980
# 20 0 days 05:04:00 3 days 06:53:39.601693          18240         24780
# 21 0 days 01:58:00 2 days 00:50:39.601693           7080          3000
# 22 0 days 01:57:00 2 days 04:48:39.601693           7020         17280
# 23 0 days 01:56:00 1 days 05:49:39.601693           6960         20940
# 24 0 days 01:56:00 2 days 05:49:39.601693           6960         20940
# 25 0 days 02:58:00 1 days 02:51:39.601693          10680         10260
# 26 0 days 01:03:00 2 days 04:53:39.601693           3780         17580
# 27 0 days 01:57:00 3 days 03:48:39.601693           7020         13680
# 28 0 days 01:57:00 2 days 03:48:39.600711           7020         13680
# 29 0 days 01:57:00 1 days 00:49:39.600711           7020          2940
# 30 0 days 01:02:00 2 days 05:53:39.600711           3720         21180
# 31 0 days 01:01:00 1 days 04:53:39.600711           3660         17580
# 32 0 days 01:59:00 3 days 04:50:39.600711           7140         17400
# 33 0 days 01:57:00 2 days 06:48:39.600711           7020         24480
# 34 0 days 04:56:00 1 days 03:48:39.600711          17760         13680
# 35 0 days 01:56:00 0 days 05:49:39.600711           6960         20940
# 36 0 days 01:55:00 1 days 03:48:39.600711           6900         13680
# 37 0 days 01:01:00 1 days 02:53:39.600711           3660         10380
# 38 0 days 01:04:00 2 days 02:52:39.600711           3840         10320
# 39 0 days 01:02:00 1 days 02:53:39.600711           3720         10380
# 40 0 days 01:03:00 1 days 02:53:39.600711           3780         10380
# 41 0 days 01:02:00 2 days 02:53:39.600711           3720         10380
# 42 0 days 01:01:00 2 days 03:49:39.600711           3660         13740
# 43 0 days 01:57:00 2 days 00:49:39.600711           7020          2940
# 44 0 days 01:57:00 1 days 03:48:39.600711           7020         13680
# 45 0 days 01:57:00 1 days 00:49:39.600711           7020          2940
# 46 0 days 01:57:00 2 days 03:48:39.600711           7020         13680
# 47 0 days 01:05:00 3 days 00:53:39.600711           3900          3180
# 48 0 days 20:03:00 0 days 22:51:39.600711          72180         82260
# 49 0 days 21:01:00 0 days 23:49:39.600711          75660         85740
# 50 0 days 16:04:00 0 days 18:52:39.600711          57840         67920
# 51 0 days 23:00:00 1 days 01:48:39.600711          82800          6480
# 52 0 days 19:04:00 0 days 21:52:39.600711          68640         78720
# 53 0 days 19:04:00 0 days 21:52:39.600711          68640         78720
# 54 0 days 17:00:00 0 days 19:48:39.600711          61200         71280
# 55 0 days 14:00:00 0 days 16:48:39.600711          50400         60480
# 56 0 days 22:05:00 1 days 00:53:39.600711          79500          3180
#
#    Distance
# 0     453.5
# 1     535.4
# 2     554.0
# 3     703.8
# 4     954.0
# 5    1026.1
# 6     735.8
# 7    1026.1
# 8     684.4
# 9     820.1
# 10    703.8
# 11    703.8
# 12    554.0
# 13    652.0
# 14    968.7
# 15    554.0
# 16    652.0
# 17   1099.4
# 18    968.7
# 19    968.7
# 20    644.5
# 21    703.8
# 22    703.8
# 23    644.5
# 24    644.5
# 25      NaN
# 26    535.4
# 27    526.7
# 28    526.7
# 29    526.7
# 30    554.0
# 31    464.3
# 32    962.9
# 33    704.3
# 34    923.6
# 35    644.5
# 36    497.8
# 37    464.3
# 38    760.1
# 39    464.3
# 40    698.0
# 41    464.3
# 42    497.8
# 43    526.7
# 44    526.7
# 45    526.7
# 46    526.7
# 47    745.9
# 48    535.4
# 49    923.6
# 50    453.5
# 51    453.5
# 52    535.4
# 53    535.4
# 54    535.4
# 55      NaN
# 56    535.4
#
# [57 rows x 66 columns]

# %%
import time
t= time.localtime()
print(str(t.tm_mday)+'/'+str(t.tm_mon)+'/'+str(t.tm_year))
# Out:
# 13/12/2022
