# %%
import pandas as pd 
import get_journey_sncf_now as gjn


df = gjn.get_OD_now(ville_origine='Bordeaux',nb_trajets=2,etranger=False,niveau_service=2,minutes_max=120)
df

# %%
tab = pd.read_csv('Outputs/results_Bordeaux_20221213T135825.csv')
tab

# %%
import affichage_vol_dest as avd

tab2 =avd.vol_dest_api('BOD')
tab2
# Out:
#                                                  id_x flyFrom code  cityFrom  \
# 0                          0498091e4b8c0000ed5716a5_0     BOD  CRL  Bordeaux
# 1                          0498032d4b8c000031670893_0     BOD  STN  Bordeaux
# 2                          049800ed4b8c0000e4b3e7cf_0     BOD  MRS  Bordeaux
# 3                          04980ec84b8c0000126f31c7_0     BOD  TSF  Bordeaux
# 4                          049809b24b8c0000e8d775ff_0     BOD  CIA  Bordeaux
# ..                                                ...     ...  ...       ...
# 80  0498057b4b8c00005fb3984f_0|0498057b4b8c00005fb...     BOD  ZRH  Bordeaux
# 81  04980e354b8c4b95511cdc9d_0|04980e354b8c4b95511...     BOD  LYS  Bordeaux
# 82                         04980c654b8b00009d731fe9_0     BOD  CMN  Bordeaux
# 83  049825c34b8c4ba0eb83a2b2_0|049825c34b8c4ba0eb8...     BOD  CDG  Bordeaux
# 84  049803584b8c4ba83dff3ae3_0|049803584b8c4ba83df...     BOD  LIS  Bordeaux
#
# ...

# %%
import time
t= time.localtime()
print(str(t.tm_mday)+'/'+str(t.tm_mon)+'/'+str(t.tm_year))
# Out:
# 13/12/2022
