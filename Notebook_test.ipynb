# %% [markdown]
# Test des fonctions utilisées

# %%
#Importation des fichiers

import affichage_gare_sncf as ags
import affichage_vol_dest as avd
import get_airports 
#import get_gares
import affichage_total
import affichage_total_def_temps

# %% [markdown]
# Affichage des gares de la base de donnée

# %%
#cartes_gares_dispo = get_gares.affichage_gares

# %% [markdown]
# Affichage des aéroports de la base de donnée

# %%
get_airports.affichage_aiport_map()

# %%
#Choix du nom de la ville recherchée

nom_recherche='Poitiers'

# %%
map = avd.affichage_vol_dest_code('KBP')
map

# %% [markdown]
# Destinations en trains

# %%
tab_dest_train = ags.requete_destinations_api(nom_recherche)   
tab_dest_train

# %%
carte_dest_train = ags.affichage_destination_map(nom_recherche)
carte_dest_train

# %%
vol = avd.affichage_vol_dest('Bordeaux')
vol
# Out:
# 1 aéroport(s) trouvé(s) pour Bordeaux.
# Recherche des destinations depuis BOD (1/1).
# Fin de la recherche des destinations pour BOD.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Destinations en avion

# %%
carte_dest_vol = avd.affichage_vol_dest(nom_recherche)
carte_dest_vol

# %% [markdown]
# Destinations Trains & Avions

# %%
carte_dest_complete = affichage_total.affichage_total(nom_recherche)
carte_dest_complete
