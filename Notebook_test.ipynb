# %% [markdown]
# Test des fonctions utilisées

# %%
#Importation des fichiers

import affichage_gare_sncf as ags
import affichage_vol_dest as avd
import get_airports 
#import get_gares
import affichage_total
import affichage_total_def_temps
# Out:
# Aucun vol au départ de KBP.
# <folium.folium.Map object at 0x0000020B8D80BDF0>
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# Affichage des gares de la base de donnée

# %%
#cartes_gares_dispo = get_gares.affichage_gares

# %% [markdown]
# Affichage des aéroports de la base de donnée

# %%
get_airports.affichage_aiport_map()
# Out:
# Carte des aeroports disponibles générée
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_387753b7550301598e22a9225338bbe1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_387753b7550301598e22a9225338bbe1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_387753b7550301598e22a9225338bbe1 = L.map(
#                 &quot;map_387753b7550301598e22a9225338bbe1&quot;,
#                 {
#                     center: [43.302222, -8.377222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9c1f53134da2c439301533d4811b260 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_387753b7550301598e22a9225338bbe1);
#
#
#             var marker_19305a850cea3cba34f27dd74f61cbfa = L.marker(
#                 [43.302222, -8.377222],
#                 {}
#             ).addTo(map_387753b7550301598e22a9225338bbe1);
#
#
#             var icon_2e31c1e16c3990f03144bddea92c14a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_19305a850cea3cba34f27dd74f61cbfa.setIcon(icon_2e31c1e16c3990f03144bddea92c14a3);
#
#
#         var popup_f3bc287d4c39fab0290d93c6974c76c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3127773e307cf2c8e03bdb489046591 = $(`&lt;div id=&quot;html_d3127773e307cf2c8e03bdb489046591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Coruña&lt;/div&gt;`)[0];
#                 popup_f3bc287d4c39fab0290d93c6974c76c8.setContent(html_d3127773e307cf2c8e03bdb489046591);
#
#
#
#         marker_19305a850cea3cba34f27dd74f61cbfa.bindPopup(popup_f3bc287d4c39fab0290d93c6974c76c8)
#         ;
#
#
#
#
#             var marker_9124323002b5a3e8b2ebf86ea890bdf7 = L.marker(
#                 [57.092778, 9.849167],
#                 {}
#             ).addTo(map_387753b7550301598e22a9225338bbe1);
#
#
#             var icon_9f8c1bb29c35273de8a0107b751baf02 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9124323002b5a3e8b2ebf86ea890bdf7.setIcon(icon_9f8c1bb29c35273de8a0107b751baf02);
#
#
#         var popup_aca85b616696894f2573404f8796954a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c942979a09aa28b46ddf391d764a377 = $(`&lt;div id=&quot;html_0c942979a09aa28b46ddf391d764a377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aalborg&lt;/div&gt;`)[0];
#                 popup_aca85b616696894f2573404f8796954a.setContent(html_0c942979a09aa28b46ddf391d764a377);
#
#
#
#         marker_9124323002b5a3e8b2ebf86ea890bdf7.bindPopup(popup_aca85b616696894f2573404f8796954a)
#         ;
#
#
#
#
#             var marker_c165cae6b575d2cc6dc5ca4fd62f277d = L.marker(
#                 [56.303889, 10.619444],
#                 {}
#             ).addTo(map_387753b7550301598e22a9225338bbe1);
#
#
#             var icon_ca2cd6ab7cc04d9084d3cf858de5810f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c165cae6b575d2cc6dc5ca4fd62f277d.setIcon(icon_ca2cd6ab7cc04d9084d3cf858de5810f);
#
#
#         var popup_dfeffc3292e71507cf55f20ba67921b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd721dc17350ed1ca100a37650d9c8e8 = $(`&lt;div id=&quot;html_cd721dc17350ed1ca100a37650d9c8e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aarhus&lt;/div&gt;`)[0];
#                 popup_dfeffc3292e71507cf55f20ba67921b1.setContent(html_cd721dc17350ed1ca100a37650d9c8e8);
#
#
#
#         marker_c165cae6b575d2cc6dc5ca4fd62f277d.bindPopup(popup_dfeffc3292e71507cf55f20ba67921b1)
#         ;
#
#
#
#
#             var marker_31a3c22e3559a4d278c13d6c7e62beb1 = L.marker(
#                 [36.711944, 5.07],
#                 {}
#             ).addTo(map_387753b7550301598e22a9225338bbe1);
#
#
#             var icon_4cad6ce0cc217fc7c169597c26126e4d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
#Choix du nom de la ville recherchée

nom_recherche='Poitiers'

# %%
map = avd.affichage_vol_dest_code('KBP')
map
# Out:
# Aucun vol au départ de KBP.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86841f2b679b3b953627967a9e92a134 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86841f2b679b3b953627967a9e92a134&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_86841f2b679b3b953627967a9e92a134 = L.map(
#                 &quot;map_86841f2b679b3b953627967a9e92a134&quot;,
#                 {
#                     center: [50.345, 30.894722],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b2b51ba2aad082b5429c23d15a9c037 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_86841f2b679b3b953627967a9e92a134);
#
#
#             var marker_f1106418e8fd749ebb4df168fb955fc4 = L.marker(
#                 [50.345, 30.894722],
#                 {}
#             ).addTo(map_86841f2b679b3b953627967a9e92a134);
#
#
#             var icon_1597fccbea1aaafaba2095e1730e5e80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f1106418e8fd749ebb4df168fb955fc4.setIcon(icon_1597fccbea1aaafaba2095e1730e5e80);
#
#
#         var popup_11bbed98e3e74b8472d78ae895e36a1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97c65cca1cfa630bc89c209a750883c0 = $(`&lt;div id=&quot;html_97c65cca1cfa630bc89c209a750883c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Boryspil International&lt;/div&gt;`)[0];
#                 popup_11bbed98e3e74b8472d78ae895e36a1a.setContent(html_97c65cca1cfa630bc89c209a750883c0);
#
#
#
#         marker_f1106418e8fd749ebb4df168fb955fc4.bindPopup(popup_11bbed98e3e74b8472d78ae895e36a1a)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Destinations en trains

# %%
tab_dest_train = ags.requete_destinations_api(nom_recherche)   
tab_dest_train
# Out:
# Les gares qui contiennent la recherche sont: 3409                  Poitiers (Poitiers)
# 3410    Poitiers Gare Routière (Poitiers)
# 4906                 Yutz Poitiers (Yutz)
# Name: label, dtype: object
# Résultats présentés pour la gare Poitiers (Poitiers) (ID: 87575001).
# c:\Users\jean-\Desktop\ENPC\Cours\MCNDU\Mobilite-1\affichage_gare_sncf.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Distance'] = departs_gares_loc.apply(add_dist_df,axis=1)
# c:\Users\jean-\Desktop\ENPC\Cours\MCNDU\Mobilite-1\affichage_gare_sncf.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Horaire'] = departs_gares_loc.apply(add_time_format,axis=1)
#                                    label        lat       lon  \
# 0                  Angoulême (Angoulême)  45.653572  0.164608
# 1   Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 2              La Rochelle (La Rochelle)  46.152705 -1.145853
# 3   Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 4                          Tours (Tours)  47.389866  0.692831
# 5         Bordeaux Saint-Jean (Bordeaux)  44.825873 -0.556697
# 6          Limoges Bénédictins (Limoges)  45.836207  1.267419
# 7   Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 8          Châtellerault (Châtellerault)  46.818594  0.549279
# 9              La Rochelle (La Rochelle)  46.152705 -1.145853
# 10                 Angoulême (Angoulême)  45.653572  0.164608
# 11  Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 12             La Rochelle (La Rochelle)  46.152705 -1.145853
# 13  Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 14                         Tours (Tours)  47.389866  0.692831
# 15        Bordeaux Saint-Jean (Bordeaux)  44.825873 -0.556697
# 16         Limoges Bénédictins (Limoges)  45.836207  1.267419
# 17  Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 18         Châtellerault (Châtellerault)  46.818594  0.549279
# 19             La Rochelle (La Rochelle)  46.152705 -1.145853
#
#         Horaire_API  Distance            Horaire
# 0   20221216T191700     104.1  19:17  16/12/2022
# 1   20221216T192200     291.9  19:22  16/12/2022
# 2   20221216T193100     123.1  19:31  16/12/2022
# 3   20221216T200400     291.9  20:04  16/12/2022
# 4   20221216T200800      93.9  20:08  16/12/2022
# 5   20221216T201900     207.2  20:19  16/12/2022
# 6   20221216T202100     109.8  20:21  16/12/2022
# 7   20221216T205300     291.9  20:53  16/12/2022
# 8   20221216T205500      31.0  20:55  16/12/2022
# 9   20221216T205800     123.1  20:58  16/12/2022
# 10  20221216T191700     104.1  19:17  16/12/2022
# 11  20221216T192200     291.9  19:22  16/12/2022
# 12  20221216T193100     123.1  19:31  16/12/2022
# 13  20221216T200400     291.9  20:04  16/12/2022
# 14  20221216T200800      93.9  20:08  16/12/2022
# 15  20221216T201900     207.2  20:19  16/12/2022
# 16  20221216T202100     109.8  20:21  16/12/2022
# 17  20221216T205300     291.9  20:53  16/12/2022
# 18  20221216T205500      31.0  20:55  16/12/2022
# 19  20221216T205800     123.1  20:58  16/12/2022

# %%
carte_dest_train = ags.affichage_destination_map(nom_recherche)
carte_dest_train
# Out:
# Les gares qui contiennent la recherche sont: 3409                  Poitiers (Poitiers)
# 3410    Poitiers Gare Routière (Poitiers)
# 4906                 Yutz Poitiers (Yutz)
# Name: label, dtype: object
# Résultats présentés pour la gare Poitiers (Poitiers) (ID: 87575001).
# Carte des Destination (Normale) des 20 prochains trains depuis la gare de Poitiers (Poitiers) générée.
# c:\Users\jean-\Desktop\ENPC\Cours\MCNDU\Mobilite-1\affichage_gare_sncf.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Distance'] = departs_gares_loc.apply(add_dist_df,axis=1)
# c:\Users\jean-\Desktop\ENPC\Cours\MCNDU\Mobilite-1\affichage_gare_sncf.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Horaire'] = departs_gares_loc.apply(add_time_format,axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe2791df3394c63ea7c0ff6ccd740657 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe2791df3394c63ea7c0ff6ccd740657&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe2791df3394c63ea7c0ff6ccd740657 = L.map(
#                 &quot;map_fe2791df3394c63ea7c0ff6ccd740657&quot;,
#                 {
#                     center: [45.653572, 0.164608],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd998d6f4d9e9b9eb180733b7f6b2579 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe2791df3394c63ea7c0ff6ccd740657);
#
#
#             var marker_e40ffa00ad77da1a9414ff201a5a1962 = L.marker(
#                 [46.582232, 0.333136],
#                 {}
#             ).addTo(map_fe2791df3394c63ea7c0ff6ccd740657);
#
#
#             var icon_c8f1b538a37bf38eda02e80b1f479b92 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e40ffa00ad77da1a9414ff201a5a1962.setIcon(icon_c8f1b538a37bf38eda02e80b1f479b92);
#
#
#         var popup_d17cb01169eb0b5990f90bfb38b9f032 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a5bfbb33c19ee4b2ce4902cc30201cba = $(`&lt;div id=&quot;html_a5bfbb33c19ee4b2ce4902cc30201cba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angoulême (Angoulême)&lt;/div&gt;`)[0];
#                 popup_d17cb01169eb0b5990f90bfb38b9f032.setContent(html_a5bfbb33c19ee4b2ce4902cc30201cba);
#
#
#
#         marker_e40ffa00ad77da1a9414ff201a5a1962.bindPopup(popup_d17cb01169eb0b5990f90bfb38b9f032)
#         ;
#
#
#
#
#             var marker_e17f91b753b03d17b823735976cd304d = L.marker(
#                 [45.653572, 0.164608],
#                 {}
#             ).addTo(map_fe2791df3394c63ea7c0ff6ccd740657);
#
#
#             var icon_24fadfb5697e7a07d5a1b415904723f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e17f91b753b03d17b823735976cd304d.setIcon(icon_24fadfb5697e7a07d5a1b415904723f2);
#
#
#         var popup_8c1f9c039abf2e4eb3cebbff02a240a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2142692504843f827d6b58bd5b71d74e = $(`&lt;div id=&quot;html_2142692504843f827d6b58bd5b71d74e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angoulême (Angoulême) - 104.1 km&lt;/div&gt;`)[0];
#                 popup_8c1f9c039abf2e4eb3cebbff02a240a8.setContent(html_2142692504843f827d6b58bd5b71d74e);
#
#
#
#         marker_e17f91b753b03d17b823735976cd304d.bindPopup(popup_8c1f9c039abf2e4eb3cebbff02a240a8)
#         ;
#
#
#
#
#             var poly_line_25443ec1077afe5f323bcd123dbe94a6 = L.polyline(
#                 [[46.582232, 0.333136], [45.653572, 0.164608]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_fe2791df3394c63ea7c0ff6ccd740657);
#
#
#             var marker_6163fce76daf8a1e997ce0b71c2f63ef = L.marker(
#                 [48.841172, 2.320514],
#                 {}
#             ).addTo(map_fe2791df3394c63ea7c0ff6ccd740657);
#
#
#             var icon_93143c9f1301121c9cc7b630005ba008 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6163fce76daf8a1e997ce0b71c2f63ef.setIcon(icon_93143c9f1301121c9cc7b630005ba008);
#
#
#         var popup_42189328b92956b69f538d4cf5fc0e02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_343a32ef2ba124838be8bdfa2caccaa4 = $(`&lt;div id=&quot;html_343a32ef2ba124838be8bdfa2caccaa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris Montparnasse Hall 1 &amp;2 (Paris) - 291.9 km&lt;/div&gt;`)

# %% [markdown]
# Destinations en avion

# %%
carte_dest_vol = avd.affichage_vol_dest(nom_recherche)
carte_dest_vol
# Out:
# 1 aéroport(s) trouvé(s) pour Poitiers.
# Recherche des destinations depuis PIS (1/1).
# Aucun vol au départ de PIS.
# Fin de la recherche des destinations pour PIS.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9fc18a5e7df83846d44ced2d2c2fc92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9fc18a5e7df83846d44ced2d2c2fc92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e9fc18a5e7df83846d44ced2d2c2fc92 = L.map(
#                 &quot;map_e9fc18a5e7df83846d44ced2d2c2fc92&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b056c7ebda1114328b1417bb19e7246 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9fc18a5e7df83846d44ced2d2c2fc92);
#
#
#             var marker_74b85c7568be383811fab926f4f49f99 = L.marker(
#                 [46.5875, 0.306667],
#                 {}
#             ).addTo(map_e9fc18a5e7df83846d44ced2d2c2fc92);
#
#
#             var icon_f3cb51c343e2479c53b43d5fb6b55445 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_74b85c7568be383811fab926f4f49f99.setIcon(icon_f3cb51c343e2479c53b43d5fb6b55445);
#
#
#         var popup_0e1756f8dbf66e034806b634403bc34e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02d1c250b03ad1b732a8d9fc98473be6 = $(`&lt;div id=&quot;html_02d1c250b03ad1b732a8d9fc98473be6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poitiers–Biard&lt;/div&gt;`)[0];
#                 popup_0e1756f8dbf66e034806b634403bc34e.setContent(html_02d1c250b03ad1b732a8d9fc98473be6);
#
#
#
#         marker_74b85c7568be383811fab926f4f49f99.bindPopup(popup_0e1756f8dbf66e034806b634403bc34e)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Destinations Trains & Avions

# %%
carte_dest_complete = affichage_total.affichage_total(nom_recherche)
carte_dest_complete
# Out:
# 1 aéroport(s) trouvé(s) pour Poitiers.
# Recherche des destinations depuis PIS (1/1).
# Aucun vol au départ de PIS.
# Fin de la recherche des destinations pour PIS.
# Les gares qui contiennent la recherche sont: 3409                  Poitiers (Poitiers)
# 3410    Poitiers Gare Routière (Poitiers)
# 4906                 Yutz Poitiers (Yutz)
# Name: label, dtype: object
# Résultats présentés pour la gare Poitiers (Poitiers) (ID: 87575001).
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbb850dc040d7c49ca62622e65ce6b48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbb850dc040d7c49ca62622e65ce6b48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_cbb850dc040d7c49ca62622e65ce6b48 = L.map(
#                 &quot;map_cbb850dc040d7c49ca62622e65ce6b48&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08f9ddbc97cc52301dbf7fd435b9eacf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cbb850dc040d7c49ca62622e65ce6b48);
#
#
#             var marker_915bc203f5690940180d2c4382851b00 = L.marker(
#                 [46.5875, 0.306667],
#                 {}
#             ).addTo(map_cbb850dc040d7c49ca62622e65ce6b48);
#
#
#             var icon_8a631d28bce677043f2064b07bb3c3e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_915bc203f5690940180d2c4382851b00.setIcon(icon_8a631d28bce677043f2064b07bb3c3e0);
#
#
#         var popup_12e3634ddf3769b7b7ad7240d0f3e472 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d15113aee8462409d8aa360725bfd1f0 = $(`&lt;div id=&quot;html_d15113aee8462409d8aa360725bfd1f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Poitiers–Biard&lt;/div&gt;`)[0];
#                 popup_12e3634ddf3769b7b7ad7240d0f3e472.setContent(html_d15113aee8462409d8aa360725bfd1f0);
#
#
#
#         marker_915bc203f5690940180d2c4382851b00.bindPopup(popup_12e3634ddf3769b7b7ad7240d0f3e472)
#         ;
#
#
#
#
#             var marker_f45a5c6a3650f7b527854c4312d08e73 = L.marker(
#                 [46.582232, 0.333136],
#                 {}
#             ).addTo(map_cbb850dc040d7c49ca62622e65ce6b48);
#
#
#             var icon_950792093e41f87ecab4ccefc22cb626 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f45a5c6a3650f7b527854c4312d08e73.setIcon(icon_950792093e41f87ecab4ccefc22cb626);
#
#
#         var popup_63cb7d2b73f3bfa189b32a5d8e1eff19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c378fb19abf278a708857df5061dd2a0 = $(`&lt;div id=&quot;html_c378fb19abf278a708857df5061dd2a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angoulême (Angoulême)&lt;/div&gt;`)[0];
#                 popup_63cb7d2b73f3bfa189b32a5d8e1eff19.setContent(html_c378fb19abf278a708857df5061dd2a0);
#
#
#
#         marker_f45a5c6a3650f7b527854c4312d08e73.bindPopup(popup_63cb7d2b73f3bfa189b32a5d8e1eff19)
#         ;
#
#
#
#
#             var marker_18cd5d913cf7f23c0d768ceaae5dd8d1 = L.marker(
#                 [45.653572, 0.164608],
#                 {}
#             ).addTo(map_cbb850dc040d7c49ca62622e65ce6b48);
#
#
#             var icon_fe37d4c92b98e6c8790a1ba26f3ea6f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18cd5d913cf7f23c0d768ceaae5dd8d1.setIcon(icon_fe37d4c92b98e6c8790a1ba26f3ea6f8);
#
#
#         var popup_83b8cd108dc58b7ab60fe5e4a2c27a7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c326962b61179fa09e3b70431898c603 = $(`&lt;div id=&quot;html_c326962b61179fa09e3b70431898c603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angoulême (Angoulême)  Distance: 104.1 km  Départ: 19:17  16/12/2022&lt;/div&gt;`)[0];
#                 popup_83b8cd108dc58b7ab60fe5e4a2c27a7a.setContent(html_c326962b61179fa09e3b70431898c603);
#
#
#
#         marker_18cd5d913cf7f23c0d768ceaae5dd8d1.bindPopup(popup_83b8cd108dc58b7ab60fe5e4a2c27a7a)
#         ;
#
#
#
#
#             var poly_line_54eec73c0ced5516b34fc8fa036f707d = L.polyline(
#                 [[46.582232, 0.333136], [45.653572, 0.164608]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&
