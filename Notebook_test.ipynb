# %% [markdown]
# Test des fonctions utilisées

# %%
#Importation des fichiers

import affichage_gare_sncf as ags
import affichage_vol_dest as avd
import get_airports 
#import get_gares
import affichage_total
import affichage_total_def_temps
# Out:
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# Affichage des gares de la base de donnée

# %%
#cartes_gares_dispo = get_gares.affichage_gares

# %% [markdown]
# Affichage des aéroports de la base de donnée

# %%
get_airports.affichage_aiport_map()
# Out:
# Carte des aeroports disponibles générée
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e95a1a0500784ef9fb465e7b4670442a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e95a1a0500784ef9fb465e7b4670442a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e95a1a0500784ef9fb465e7b4670442a = L.map(
#                 &quot;map_e95a1a0500784ef9fb465e7b4670442a&quot;,
#                 {
#                     center: [43.302222, -8.377222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_239b21bbc305cb342cf9f554c839651c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e95a1a0500784ef9fb465e7b4670442a);
#
#
#             var marker_565505ee3d381c0aab4e1b758f39815e = L.marker(
#                 [43.302222, -8.377222],
#                 {}
#             ).addTo(map_e95a1a0500784ef9fb465e7b4670442a);
#
#
#             var icon_aa9f28356df08189d9e6081ca0c85a31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_565505ee3d381c0aab4e1b758f39815e.setIcon(icon_aa9f28356df08189d9e6081ca0c85a31);
#
#
#         var popup_86b0586145b46607a4e8a76b5e10925a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6db5f2835833436f400d26090e698a70 = $(`&lt;div id=&quot;html_6db5f2835833436f400d26090e698a70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Coruña&lt;/div&gt;`)[0];
#                 popup_86b0586145b46607a4e8a76b5e10925a.setContent(html_6db5f2835833436f400d26090e698a70);
#
#
#
#         marker_565505ee3d381c0aab4e1b758f39815e.bindPopup(popup_86b0586145b46607a4e8a76b5e10925a)
#         ;
#
#
#
#
#             var marker_92c0a88c79ed640a144b9a5349d41e18 = L.marker(
#                 [57.092778, 9.849167],
#                 {}
#             ).addTo(map_e95a1a0500784ef9fb465e7b4670442a);
#
#
#             var icon_7a66f75f6acf4a235f0b970019f10548 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_92c0a88c79ed640a144b9a5349d41e18.setIcon(icon_7a66f75f6acf4a235f0b970019f10548);
#
#
#         var popup_9136a01e9f58f6c43f33ad302f0936c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef9924a920518ac9a5c4aca83c5862b5 = $(`&lt;div id=&quot;html_ef9924a920518ac9a5c4aca83c5862b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aalborg&lt;/div&gt;`)[0];
#                 popup_9136a01e9f58f6c43f33ad302f0936c8.setContent(html_ef9924a920518ac9a5c4aca83c5862b5);
#
#
#
#         marker_92c0a88c79ed640a144b9a5349d41e18.bindPopup(popup_9136a01e9f58f6c43f33ad302f0936c8)
#         ;
#
#
#
#
#             var marker_8b71b41124b71a17e3293522ff51f251 = L.marker(
#                 [56.303889, 10.619444],
#                 {}
#             ).addTo(map_e95a1a0500784ef9fb465e7b4670442a);
#
#
#             var icon_8dd48875308d8a44d0ac0d2923ffa090 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b71b41124b71a17e3293522ff51f251.setIcon(icon_8dd48875308d8a44d0ac0d2923ffa090);
#
#
#         var popup_b9078cf091db80a7207b3d73413a19c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53c7feaa3888d2dc42467dd79bf90481 = $(`&lt;div id=&quot;html_53c7feaa3888d2dc42467dd79bf90481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aarhus&lt;/div&gt;`)[0];
#                 popup_b9078cf091db80a7207b3d73413a19c5.setContent(html_53c7feaa3888d2dc42467dd79bf90481);
#
#
#
#         marker_8b71b41124b71a17e3293522ff51f251.bindPopup(popup_b9078cf091db80a7207b3d73413a19c5)
#         ;
#
#
#
#
#             var marker_cf0d13a1e25d50bd69c5e79318bd850f = L.marker(
#                 [36.711944, 5.07],
#                 {}
#             ).addTo(map_e95a1a0500784ef9fb465e7b4670442a);
#
#
#             var icon_3c35ca4e40dc3586588d26a2697a9e59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
#Choix du nom de la ville recherchée

nom_recherche='Poitiers'

# %% [markdown]
# Destinations en trains

# %%
tab_dest_train = ags.requete_destinations_api(nom_recherche)   
tab_dest_train
# Out:
# Les gares qui contiennent la recherche sont: 3409                  Poitiers (Poitiers)
# 3410    Poitiers Gare Routière (Poitiers)
# 4906                 Yutz Poitiers (Yutz)
# Name: label, dtype: object
# Résultats présentés pour la gare Poitiers (Poitiers) (ID: 87575001).
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Distance'] = departs_gares_loc.apply(add_dist_df,axis=1)
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Horaire'] = departs_gares_loc.apply(add_time_format,axis=1)
#                                    label        lat       lon  \
# 0              La Rochelle (La Rochelle)  46.152705 -1.145853
# 1                  Angoulême (Angoulême)  45.653572  0.164608
# 2                          Tours (Tours)  47.389866  0.692831
# 3   Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 4              La Rochelle (La Rochelle)  46.152705 -1.145853
# 5         Bordeaux Saint-Jean (Bordeaux)  44.825873 -0.556697
# 6          Limoges Bénédictins (Limoges)  45.836207  1.267419
# 7          Châtellerault (Châtellerault)  46.818594  0.549279
# 8                          Tours (Tours)  47.389866  0.692831
# 9          Châtellerault (Châtellerault)  46.818594  0.549279
# 10             La Rochelle (La Rochelle)  46.152705 -1.145853
# 11                 Angoulême (Angoulême)  45.653572  0.164608
# 12                         Tours (Tours)  47.389866  0.692831
# 13  Paris Montparnasse Hall 1 &2 (Paris)  48.841172  2.320514
# 14             La Rochelle (La Rochelle)  46.152705 -1.145853
# 15        Bordeaux Saint-Jean (Bordeaux)  44.825873 -0.556697
# 16         Limoges Bénédictins (Limoges)  45.836207  1.267419
# 17         Châtellerault (Châtellerault)  46.818594  0.549279
# 18                         Tours (Tours)  47.389866  0.692831
# 19         Châtellerault (Châtellerault)  46.818594  0.549279
#
#         Horaire_API  Distance            Horaire
# 0   20221202T191200     123.1  19:12  02/12/2022
# 1   20221202T191700     104.1  19:17  02/12/2022
# 2   20221202T200100      93.9  20:01  02/12/2022
# 3   20221202T200800     291.9  20:08  02/12/2022
# 4   20221202T200900     123.1  20:09  02/12/2022
# 5   20221202T201400     207.2  20:14  02/12/2022
# 6   20221202T203300     109.8  20:33  02/12/2022
# 7   20221202T205500      31.0  20:55  02/12/2022
# 8   20221203T073600      93.9  07:36  03/12/2022
# 9   20221203T074800      31.0  07:48  03/12/2022
# 10  20221202T191200     123.1  19:12  02/12/2022
# 11  20221202T191700     104.1  19:17  02/12/2022
# 12  20221202T200100      93.9  20:01  02/12/2022
# 13  20221202T200800     291.9  20:08  02/12/2022
# 14  20221202T200900     123.1  20:09  02/12/2022
# 15  20221202T201400     207.2  20:14  02/12/2022
# 16  20221202T203300     109.8  20:33  02/12/2022
# 17  20221202T205500      31.0  20:55  02/12/2022
# 18  20221203T073600      93.9  07:36  03/12/2022
# 19  20221203T074800      31.0  07:48  03/12/2022

# %%
carte_dest_train = ags.affichage_destination_map(nom_recherche)
carte_dest_train
# Out:
# Les gares qui contiennent la recherche sont: 3409                  Poitiers (Poitiers)
# 3410    Poitiers Gare Routière (Poitiers)
# 4906                 Yutz Poitiers (Yutz)
# Name: label, dtype: object
# Résultats présentés pour la gare Poitiers (Poitiers) (ID: 87575001).
# Carte des Destination (Normale) des 20 prochains trains depuis la gare de Poitiers (Poitiers) générée.
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Distance'] = departs_gares_loc.apply(add_dist_df,axis=1)
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Horaire'] = departs_gares_loc.apply(add_time_format,axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aea05e1b624620d54ae51267b9a48eb4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aea05e1b624620d54ae51267b9a48eb4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_aea05e1b624620d54ae51267b9a48eb4 = L.map(
#                 &quot;map_aea05e1b624620d54ae51267b9a48eb4&quot;,
#                 {
#                     center: [46.152705, -1.145853],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b49dee2a09b899d8c2b38392b0acb0a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aea05e1b624620d54ae51267b9a48eb4);
#
#
#             var marker_e0ff988e6cffacc48d4353f00d61f78e = L.marker(
#                 [46.582232, 0.333136],
#                 {}
#             ).addTo(map_aea05e1b624620d54ae51267b9a48eb4);
#
#
#             var icon_4110d89fb61e9ae006539fb1f0be61d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0ff988e6cffacc48d4353f00d61f78e.setIcon(icon_4110d89fb61e9ae006539fb1f0be61d8);
#
#
#         var popup_ccfc7a0078bdf938d8b6bcf013e64424 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7de8fbe618591c7ab24a6a454a8a5838 = $(`&lt;div id=&quot;html_7de8fbe618591c7ab24a6a454a8a5838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Rochelle (La Rochelle)&lt;/div&gt;`)[0];
#                 popup_ccfc7a0078bdf938d8b6bcf013e64424.setContent(html_7de8fbe618591c7ab24a6a454a8a5838);
#
#
#
#         marker_e0ff988e6cffacc48d4353f00d61f78e.bindPopup(popup_ccfc7a0078bdf938d8b6bcf013e64424)
#         ;
#
#
#
#
#             var marker_cf2f3a0cb4d47811180a222462d12c10 = L.marker(
#                 [46.152705, -1.145853],
#                 {}
#             ).addTo(map_aea05e1b624620d54ae51267b9a48eb4);
#
#
#             var icon_95f3e93bb991d876c439ac5306e2f453 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf2f3a0cb4d47811180a222462d12c10.setIcon(icon_95f3e93bb991d876c439ac5306e2f453);
#
#
#         var popup_af8594e7c0b1761a666a7141b11e2ef5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d4cb1730926aa0002ec9161b113d6d1 = $(`&lt;div id=&quot;html_1d4cb1730926aa0002ec9161b113d6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Rochelle (La Rochelle) - 123.1 km&lt;/div&gt;`)[0];
#                 popup_af8594e7c0b1761a666a7141b11e2ef5.setContent(html_1d4cb1730926aa0002ec9161b113d6d1);
#
#
#
#         marker_cf2f3a0cb4d47811180a222462d12c10.bindPopup(popup_af8594e7c0b1761a666a7141b11e2ef5)
#         ;
#
#
#
#
#             var poly_line_8e004956600b9fee2703fd3a59d475dc = L.polyline(
#                 [[46.582232, 0.333136], [46.152705, -1.145853]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_aea05e1b624620d54ae51267b9a48eb4);
#
#
#             var marker_6fefe214c2c2352f391f4721aa157435 = L.marker(
#                 [45.653572, 0.164608],
#                 {}
#             ).addTo(map_aea05e1b624620d54ae51267b9a48eb4);
#
#
#             var icon_04b3dd8629de2102621d0f90f7bb4612 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fefe214c2c2352f391f4721aa157435.setIcon(icon_04b3dd8629de2102621d0f90f7bb4612);
#
#
#         var popup_4e8c7e1fce36eed65cc0141f58fa8b31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dc7179174e339767d400a11525f7d7f = $(`&lt;div id=&quot;html_9dc7179174e339767d400a11525f7d7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angoulême (Angoulême) - 104.1 km&lt;/div&gt;`)[0];

# %% [markdown]
# Destinations en avion

# %%
carte_dest_vol = avd.affichage_vol_dest(nom_recherche)
carte_dest_vol
# Out:
# 1 aéroport(s) trouvé(s) pour Poitiers.
# Recherche des destinations depuis PIS (1/1).
# Aucun vol au départ de PIS.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tps_trajet'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3750         try:
# -> 3751             loc = self._info_axis.get_loc(key)
#    3752         except KeyError:
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#
# KeyError: 'Tps_trajet'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28580/3597527222.py in <module>
# ----> 1 carte_dest_vol = avd.affichage_vol_dest(nom_recherche)
#       2 carte_dest_vol
#
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_vol_dest.py in affichage_vol_dest(nom_recherche)
#     149         print('Recherche des destinations depuis ' + str(code_aeroport) +' (' + str(i+1) + '/' + str(nombre_aeroports) + ').' )
#     150         airports_liste = pd.read_csv('Data/ensemble_airports.csv')
# --> 151         airports_dest=vol_dest_api(code_aeroport)
#     152
#     153         airport_ori = airports_liste[airports_liste['code']==str(code_aeroport)]
#
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_vol_dest.py in vol_dest_api(code)
#      57         return(delta_time_api(x['utc_departure'],x['utc_arrival']))
#      58
# ---> 59     dest['Tps_trajet']= dest.apply(temps_vol,axis=1)
#      60
#      61     def temps_vol_sec(x):
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3740         # now align rows
#    3741         arraylike = _reindex_for_setitem(value, self.index)
# -> 3742         self._set_item_mgr(key, arraylike)
#    3743
#    3744     def _iset_item_mgr(self, loc: int | slice | np.ndarray, value) -> None:
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_mgr(self, key, value)
#    3752         except KeyError:
#    3753             # This item wasn't present, just insert at end
# -> 3754             self._mgr.insert(len(self._info_axis), key, value)
#    3755         else:
#    3756             self._iset_item_mgr(loc, value)
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value)
#    1160             value = ensure_block_shape(value, ndim=self.ndim)
#    1161
# -> 1162         block = new_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1163
#    1164         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in new_block(values, placement, ndim, klass)
#    1935
#    1936     values, _ = extract_pandas_array(values, None, ndim)
# -> 1937     check_ndim(values, placement, ndim)
#    1938
#    1939     if klass is None:
#
# c:\Users\jean-\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in check_ndim(values, placement, ndim)
#    1977             )
#    1978         if len(placement) != len(values):
# -> 1979             raise ValueError(
#    1980                 f"Wrong number of items passed {len(values)}, "
#    1981                 f"placement implies {len(placement)}"
#
# ValueError: Wrong number of items passed 0, placement implies 1

# %% [markdown]
# Destinations Trains & Avions

# %%
carte_dest_complete = affichage_total.affichage_total(nom_recherche)
carte_dest_complete
# Out:
# 1 aéroport(s) trouvé(s) pour Nantes.
# Recherche des destinations depuis NTE (1/1).
# Fin de la recherche des destinations pour NTE.
# Les gares qui contiennent la recherche sont: 3090           Nantes (Nantes)
# 3091    Nantes Pirmil (Nantes)
# Name: label, dtype: object
# Résultats présentés pour la gare Nantes (Nantes) (ID: 87481002).
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Distance'] = departs_gares_loc.apply(add_dist_df,axis=1)
# c:\Users\jean-\Desktop\Git_MCNDU\MCNDU\MCNDU\affichage_gare_sncf.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   departs_gares_loc['Horaire'] = departs_gares_loc.apply(add_time_format,axis=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63d5e10264f0ead2598aaf3e6d5375fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63d5e10264f0ead2598aaf3e6d5375fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_63d5e10264f0ead2598aaf3e6d5375fb = L.map(
#                 &quot;map_63d5e10264f0ead2598aaf3e6d5375fb&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cfbd52a1336b1f1f23da672fd441c9f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_63d5e10264f0ead2598aaf3e6d5375fb);
#
#
#             var marker_5f18cabcf5f69bc8bd74862ff802d39a = L.marker(
#                 [47.156944, -1.607778],
#                 {}
#             ).addTo(map_63d5e10264f0ead2598aaf3e6d5375fb);
#
#
#             var icon_e6c87b0c650b58ba220c98b222d59387 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f18cabcf5f69bc8bd74862ff802d39a.setIcon(icon_e6c87b0c650b58ba220c98b222d59387);
#
#
#         var popup_2068e3eed6df4ce6ad95a539857c324f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99dac97db2a5d2cd84f0eb786c9d2977 = $(`&lt;div id=&quot;html_99dac97db2a5d2cd84f0eb786c9d2977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nantes Atlantique&lt;/div&gt;`)[0];
#                 popup_2068e3eed6df4ce6ad95a539857c324f.setContent(html_99dac97db2a5d2cd84f0eb786c9d2977);
#
#
#
#         marker_5f18cabcf5f69bc8bd74862ff802d39a.bindPopup(popup_2068e3eed6df4ce6ad95a539857c324f)
#         ;
#
#
#
#
#             var marker_0b38a1f02f58ecec69a2c75f5e5484cc = L.marker(
#                 [40.493611, -3.566667],
#                 {}
#             ).addTo(map_63d5e10264f0ead2598aaf3e6d5375fb);
#
#
#             var icon_951fc36fafd993e9fcf2d6c3833e6dcc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0b38a1f02f58ecec69a2c75f5e5484cc.setIcon(icon_951fc36fafd993e9fcf2d6c3833e6dcc);
#
#
#         var popup_2c0248a11467906e4126cbda18b4930e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45ac48dd048f1bded8d90a24d24fd60c = $(`&lt;div id=&quot;html_45ac48dd048f1bded8d90a24d24fd60c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Madrid  Distance: 757.3  Temps de trajet: 0 days 01:58:00&lt;/div&gt;`)[0];
#                 popup_2c0248a11467906e4126cbda18b4930e.setContent(html_45ac48dd048f1bded8d90a24d24fd60c);
#
#
#
#         marker_0b38a1f02f58ecec69a2c75f5e5484cc.bindPopup(popup_2c0248a11467906e4126cbda18b4930e)
#         ;
#
#
#
#
#             var poly_line_1c7fa41d12b6fbbaf351b13d40a2d12c = L.polyline(
#                 [[47.156944, -1.607778], [40.493611, -3.566667]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_63d5e10264f0ead2598aaf3e6d5375fb);
#
#
#             var marker_ee71bc25f9c675c47649150cc243df6b = L.marker(
#                 [40.493611, -3.566667],
#                 {}
#             ).addTo(map_63d5e10264f0ead2598aaf3e6d5375fb);
#
#
#             var icon_a28425a2744d06122b4dccdccaa2b77e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee71bc25f9c675c47649150cc243df6b.setIcon(icon_a28425a2744d06122b4dccdccaa2b77e);
#
#
#         var popup_74b3c459af8d41f428050c543e651d2d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f784448ced75298e2cc1815da1a1af5b = $(`&lt;div id=&quot;html_f784448ced75298e2cc1815da1a1af5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Madrid  Distance: 757.3  Temps de trajet: 0 days
